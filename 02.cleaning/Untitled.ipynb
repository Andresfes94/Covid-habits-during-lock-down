# %%
import requests
import json
import os

import pandas as pd

# %%
pd.read_csv(os.path.join("aggregated_country_streams.csv"))
# Out:
#      Unnamed: 0   streams streams.1 streams.2 streams.3 streams.4  streams.5  \
# 0       country       AUT       BEL       BGR       CYP       CZE        DEU
# 1          date       NaN       NaN       NaN       NaN       NaN        NaN
# 2    2018-08-24  10301612  12348795    985485    328417   4869155  142899503
# 3    2018-08-31   9508616  12634840   1136095    384379   5207132  148764686
# 4    2018-09-07   9717264  12538824   1043073    340697   5010547  142763299
# ..          ...       ...       ...       ...       ...       ...        ...
# 101  2020-07-17  12421511  18756779   1652278    672939   8650267  192973906
# 102  2020-07-24  13113467  17877532   1655013    653948   8489350  204359911
# 103  2020-07-31  12969684  18737612   1623495    648896   8505070  210775980
# 104  2020-08-07  12687619  18352306   1640165    661870   8616465  200822741
# 105  2020-08-14  12145822  17885290   1652316    640447   9339769  188445427
#
# ...
